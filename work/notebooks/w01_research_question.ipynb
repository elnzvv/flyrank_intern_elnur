# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/elnzvv/flyrank_intern_elnur/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm choosing Lane 2: Refresh / Content Opportunity Scoring. In the Week 1-2
# starter notebooks I already built a hand-written rule (stale x visible pages)
# and compared it to a depth-2 decision tree, so this lane extends work I've
# already started. I'm interested in how a transparent scoring system can help
# a content team prioritize their limited review capacity.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Which pages should be reviewed first for refresh, given limited reviewer
# capacity? Unit of analysis: one content page. The action a reviewer could
# take is to refresh, expand, or monitor a flagged page. The cost of a wrong
# recommendation is wasted reviewer time on a page that wasn't actually a
# priority, and the opportunity cost of NOT reviewing a page that was quietly
# losing visibility. Data and ML can help because manually scanning hundreds
# of thousands of pages isn't feasible — a ranked, evidence-backed queue lets
# a small team focus on the highest-value candidates first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/elnzvv/flyrank_intern_elnur"
REPO_DIR = "flyrank_intern_elnur"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Stale + visible pages: {stale_visible} out of {len(df)}")

print(f"Declining rate overall: {df['trend_direction'].str.lower().eq('down').mean():.3f}")
# Out:
# Stale + visible pages: 17 out of 30000
# Declining rate overall: 0.542

# %% [markdown]
# This work is observational, not experimental — I can say what I OBSERVED
# in the data (e.g. "X% of pages are stale and visible") and what patterns
# are DIRECTIONAL (e.g. "declining pages tend to cluster around low CTR at
# a given position"). This supports DECISION-SUPPORT: helping a reviewer
# prioritize where to look first.
#
# I cannot claim that refreshing a flagged page will CAUSE it to recover —
# that would require a controlled experiment, not just historical data. I
# also cannot claim to have found a Google ranking factor, or to be
# "predicting Google's algorithm" — I'm only measuring what happened in
# FlyRank's observed data, not reverse-engineering search engine logic.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
